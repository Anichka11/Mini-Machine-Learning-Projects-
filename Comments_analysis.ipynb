# %%
import pandas as pd
import re
movies =pd.read_csv("imdb_movies.csv",encoding='latin-1')
movies.columns =['text','label']
movies['text'] =movies['text'].map(lambda x : re.sub(r'\d+',"",x))
movies['text'] =movies['text'].map(lambda x: re.sub(r'[\([{})\]]',"",x))
movies=movies.head(20000)
movies.head()
# Out:
#                                                 text  label
# 0  I grew up b.  watching and loving the Thunderb...      0
# 1  When I put this movie in my DVD player, and sa...      0
# 2  Why do people who do not know what a particula...      0
# 3  Even though I have great interest in Biblical ...      0
# 4  Im a die hard Dads Army fan and nothing will e...      1

# %%
movies.shape
# Out:
# (20000, 2)

# %%
y = movies['label']
X = movies['text']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=1)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
transformer = TfidfVectorizer(stop_words='english',max_features=12000)
X_train = transformer.fit_transform(X_train).toarray()
X_test = transformer.fit_transform(X_test).toarray()

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(criterion = 'entropy')
model.fit(X_train,y_train)
model.score(X_test,y_test)
# Out:
# 0.49666666666666665

# %%
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA
hybrid=Pipeline(steps=[("pca",PCA(n_components=200)),("model",DecisionTreeClassifier())])
hybrid.fit(X_train,y_train)
hybrid.score(X_test,y_test)
# Out:
# 0.5018333333333334

# %%
from  bs4  import BeautifulSoup
import requests
url ='https://sportall.ge/fekhburthi/fekhburthii/legionerebi/174649-ra-ushlis-saqarthvelos-nakrebs-khels-ufro-didi-miznebisken-sad-varth-obieqturad.html'
content =requests.get(url).text
content =BeautifulSoup(content,'html.parser')

# %%
text =content.find_all("div",class_='c_comment')[0].text.strip()

# %%
pip install deep-translator
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 2.6 MB/s eta 0:00:00
# ...

# %%
from deep_translator import GoogleTranslator
translated = GoogleTranslator(source='auto', target='en').translate(text)
print(translated)
# Out:
# The fact is, these guys are playing perfectly in their respective clubs.

# %%
X_train.shape
# Out:
# (14000, 12000)
